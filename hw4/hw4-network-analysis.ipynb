# %% [markdown]
# # HW4 - Analyzing Bias in Networks - DSCI 531 - Spring 2023|
#
# ### Please complete the code or analysis under “TODO”. 70pts in total. You should run every cell and keep all the outputs before submitting. Failing to include your outputs will result in zero points.
#
# ### Please keep in mind the academic integrity. Plagiarism will be taken seriously.

# %% [markdown]
# ## Reading Data

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
from collections import Counter


chicago_mat = loadmat('Data/UChicago.mat')
chicago_adj = chicago_mat['A']
chicago_info = chicago_mat['local_info']


caltech_mat = loadmat('Data/Caltech.mat')
caltech_adj = caltech_mat['A']
caltech_info = caltech_mat['local_info']

print("Chicago graph")
print(f"number of nodes={chicago_adj.shape[0]}")
print(f"number of edges={int(np.sum(chicago_adj)//2)}")
print()

chicago_gender = np.zeros(chicago_adj.shape[0], dtype=int)
chicago_gender[chicago_info[:, 1] == 1] = 1
chicago_gender[chicago_info[:, 1] == 2] = 2
print(f"Genders: \n\t#0 = {len(chicago_gender[chicago_gender == 0])} \n\t#1 = {len(chicago_gender[chicago_gender == 1])} \n\t#2 = {len(chicago_gender[chicago_gender == 2])}")
print()


print("Caltech graph: ")
print(f"number of nodes={caltech_adj.shape[0]}")
print(f"number of edges={int(np.sum(caltech_adj)//2)}")
print()


caltech_gender = np.zeros(caltech_adj.shape[0], dtype=int)
caltech_gender[caltech_info[:, 1] == 1] = 1
caltech_gender[caltech_info[:, 1] == 2] = 2

print("")
print("caltech genders: \n\t#0 = {} \n\t#1 = {} \n\t#2 = {}".format(len(caltech_gender[caltech_gender == 0]), len(caltech_gender[caltech_gender == 1]), len(caltech_gender[caltech_gender == 2])))
# Out:
# Chicago graph
# number of nodes=6591
# number of edges=208103
#
# Genders:
# 	#0 = 673
# 	#1 = 2875
# 	#2 = 3043
#
# Caltech graph:
# number of nodes=769
# number of edges=16656
#
#
# caltech genders:
# 	#0 = 66
# 	#1 = 228
# 	#2 = 475

# %% [markdown]
# ## Analysis of Centrality
# ### Compute Centrality Scores for Caltech and Chicago, and compare them.

# %%
def compare_nodes_centrality(centrality_name, chi_measure, chi_gender, cal_measure, cal_gender):
    """
    Show information about centrality measure
    :centrality_name (string): the title of the plot i.e.: PageRank, Degree Centrality, ...
    :chi_measure (dict): Chicago nodes centrality measures. keys are nodes, values are centrality measure
    :chi_gender (list): Gender of Chicago nodes -- chicago_gender array
    :cal_measure (dict): Caltech nodes centrality measures. keys are nodes, values are centrality measure
    :cal_gender (list): Gender of Caltech nodes -- caltech_gender array
    """
    
    
    plt.clf()
    fig, axs = plt.subplots(1, 3)
    
    chi_all = list(chi_measure.values())
    cal_all = list(cal_measure.values())
    axs[0].hist(chi_all, bins=50, color='red', alpha=0.6, label='Chicago', density=False)
    axs[0].hist(cal_all, bins=50, color='blue', alpha=0.6, label='Caltech', density=False)
    axs[0].set_yscale('log')
    axs[0].set_xlabel('value')
    axs[0].set_ylabel('frequency')
    axs[0].legend(loc='upper right')
    axs[0].set_title("All nodes " + centrality_name)
    
    chi_gen_1 = [val for key, val in chi_measure.items() if key in np.where(chi_gender == 1)[0]]
    cal_gen_1 = [val for key, val in cal_measure.items() if key in np.where(cal_gender == 1)[0]]
    axs[1].hist(chi_gen_1, bins=50, color='red', alpha=0.6, label='Chicago', density=False)
    axs[1].hist(cal_gen_1, bins=50, color='blue', alpha=0.6, label='Caltech', density=False)
    axs[1].set_yscale('log')
    axs[1].set_xlabel('value')
    axs[1].legend(loc='upper right')
    axs[1].set_title("Gender 1 " + centrality_name)
    
    chi_gen_2 = [val for key, val in chi_measure.items() if key in np.where(chi_gender == 2)[0]]
    cal_gen_2 = [val for key, val in cal_measure.items() if key in np.where(cal_gender == 2)[0]]
    axs[2].hist(chi_gen_2, bins=50, color='red', alpha=0.6, label='Chicago', density=False)
    axs[2].hist(cal_gen_2, bins=50, color='blue', alpha=0.6, label='Caltech', density=False)
    axs[2].set_yscale('log')
    axs[2].set_xlabel('value')
    axs[2].legend(loc='upper right')
    axs[2].set_title("Gender 2 " + centrality_name)
    
    fig.set_size_inches(18.5, 6.5)
    plt.show()
    
    print("{} mean and std:".format(centrality_name))
    
    print("\tChicago:")
    print("\t\tAll = {0:.3f} (+- {1:.4f})".format(np.mean(chi_all), np.std(chi_all)))
    print("\t\tGender 1 = {0:.3f} (+- {1:.4f})".format(np.mean(chi_gen_1), np.std(chi_gen_1)))
    print("\t\tGender 2 = {0:.3f} (+- {1:.4f})".format(np.mean(chi_gen_2), np.std(chi_gen_2)))
    
    print("\tCaltech:")
    print("\t\tAll = {0:.3f} (+- {1:.4f})".format(np.mean(cal_all), np.std(cal_all)))
    print("\t\tGender 1 = {0:.3f} (+- {1:.4f})".format(np.mean(cal_gen_1), np.std(cal_gen_1)))
    print("\t\tGender 2 = {0:.3f} (+- {1:.4f})".format(np.mean(cal_gen_2), np.std(cal_gen_2)))
    
    print ("")


    
# This is a toy test to help you better understand what this function does.
chi_measure = {
    0: 5,
    1: 6,
    2: 1,
    3: 2
}
chi_gender = np.array([1, 1, 2, 2])

cal_measure = {
    0: 8,
    1: 4,
    2: 9,
    3: 5
}
cal_gender = np.array([1, 1, 2, 2])
compare_nodes_centrality('SampleMeasure', chi_measure, chi_gender, cal_measure, cal_gender)
# Out:
# SampleMeasure mean and std:
# 	Chicago:
# 		All = 3.500 (+- 2.0616)
# 		Gender 1 = 5.500 (+- 0.5000)
# 		Gender 2 = 1.500 (+- 0.5000)
# 	Caltech:
# 		All = 6.500 (+- 2.0616)
# 		Gender 1 = 6.000 (+- 2.0000)
# 		Gender 2 = 7.000 (+- 2.0000)

# %%
import networkx as nx

# create the networkx objects for the two graphs
G_chicago = nx.from_scipy_sparse_array(chicago_adj)
G_caltech = nx.from_scipy_sparse_array(caltech_adj)

# %%
# compute the betweenness centrality scores (dict, keys are nodes, values are centrality measure) for Chicago and Caltech
# TODO. 4pts
chi_betweenness = nx.betweenness_centrality(G_chicago)
cal_betweenness = nx.betweenness_centrality(G_caltech)

compare_nodes_centrality('Betweenness', chi_betweenness, chicago_gender, cal_betweenness, caltech_gender)
# Out:
# Betweenness mean and std:
# 	Chicago:
# 		All = 0.000 (+- 0.0015)
# 		Gender 1 = 0.000 (+- 0.0005)
# 		Gender 2 = 0.000 (+- 0.0009)
# 	Caltech:
# 		All = 0.002 (+- 0.0038)
# 		Gender 1 = 0.002 (+- 0.0043)
# 		Gender 2 = 0.002 (+- 0.0037)

# %%
# compute the degreee centrality scores (dict, keys are nodes, values are centrality measure) for Chicago and Caltech
# TODO. 4pts
chi_degree = nx.degree_centrality(G_chicago)
cal_degree = nx.degree_centrality(G_caltech)

compare_nodes_centrality('degree', chi_degree, chicago_gender, cal_degree, caltech_gender)
# Out:
# degree mean and std:
# 	Chicago:
# 		All = 0.010 (+- 0.0097)
# 		Gender 1 = 0.010 (+- 0.0092)
# 		Gender 2 = 0.010 (+- 0.0094)
# 	Caltech:
# 		All = 0.056 (+- 0.0482)
# 		Gender 1 = 0.068 (+- 0.0492)
# 		Gender 2 = 0.055 (+- 0.0466)

# %%
# compute the eigenvector centrality scores (dict, keys are nodes, values are centrality measure) for Chicago and Caltech
# TODO. 4pts
chi_eigen = nx.eigenvector_centrality(G_chicago, max_iter=1000)
cal_eigen = nx.eigenvector_centrality(G_caltech, max_iter=1000)

compare_nodes_centrality('eigen', chi_eigen, chicago_gender, cal_eigen, caltech_gender)
# Out:
# eigen mean and std:
# 	Chicago:
# 		All = 0.008 (+- 0.0096)
# 		Gender 1 = 0.008 (+- 0.0097)
# 		Gender 2 = 0.008 (+- 0.0092)
# 	Caltech:
# 		All = 0.027 (+- 0.0234)
# 		Gender 1 = 0.034 (+- 0.0242)
# 		Gender 2 = 0.027 (+- 0.0224)

# %% [markdown]
# ### Which university has more gender gap in terms of centrality? Which centrality score(s) show(s) such gender gap?  Give your insights on why this university has higher gender gap on the centrality score(s). 4pts
#
# #### <font color="red">Please type your response here.</font>
#
# 1. **Caltech** exhibits a higher gender gap in centrality scores compared to Chicago.
#
#     * In Chicago, the centrality measures for Gender 1 and Gender 2 are nearly identical across all three metrics (Betweenness, Degree, and Eigenvector).
#
#     * In Caltech, the centrality scores for Gender 1 tend to be slightly higher than those for Gender 2, especially in Degree and Eigenvector Centrality.
#
# 2. **Degree Centrality** and **Eigenvector Centrality**
#
#     * **Degree Centrality**:
#         In Caltech, Gender 1 has a higher mean degree (0.068) compared to Gender 2 (0.055), with a larger standard deviation.
#         In Chicago, both genders have nearly identical degree means (0.010), suggesting no significant gender gap in node connectivity.
#
#     * **Eigenvector Centrality**:
#         In Caltech, Gender 1 has a higher mean eigenvector centrality (0.034) than Gender 2 (0.027).
#         In Chicago, the mean eigenvector centrality for both genders is nearly the same (0.008), indicating no disparity.
#
#     * **Betweenness Centrality**
#         does not show significant gender differences in either university. The mean betweenness is near zero for all groups, and the small standard deviations indicate that nodes rarely serve as bridges in these networks.
#
# 3. Why
#
#     a. **Network Structure Differences**:
#
#     The Caltech network appears to be more hierarchical, where some individuals (more likely from Gender 1) form more central or influential positions (higher degree and eigenvector centrality).
#
#     In contrast, Chicago’s network seems to be more egalitarian, with little difference between genders in connectivity.
#
#     b. **Social or Institutional Factors**:
#
#     There may be gender-based clustering in Caltech, where Gender 1 is more likely to be part of highly interconnected hubs, leading to higher eigenvector centrality.
#
#     This could be influenced by participation in social groups, academic disciplines, or historical patterns of gender representation in leadership roles.
#
#     c. **Degree Distribution Differences**:
#
#     The larger mean and standard deviation for Degree in Caltech suggest that some individuals (mostly from Gender 1) have significantly more connections, which influences their eigenvector centrality.
#
#     Chicago has a much lower degree mean (0.010) with almost no gender difference, implying a more evenly distributed social network.

# %% [markdown]
# ### Analyze the correlation between different centrality scores

# %%
# find the Spearman's rank correlation among the four centrality scores on Chicago
# TODO. 3pts

from scipy.stats import spearmanr
# compute the PageRank scores
chi_pagerank = nx.pagerank(G_chicago)
cal_pagerank = nx.pagerank(G_caltech)
corr_pagerank_betweeness_chi = spearmanr(list(chi_pagerank.values()), list(chi_betweenness.values())).correlation
corr_pagerank_degree_chi = spearmanr(list(chi_pagerank.values()), list(chi_degree.values())).correlation
corr_pagerank_eigen_chi = spearmanr(list(chi_pagerank.values()), list(chi_eigen.values())).correlation
corr_betweenness_degree_chi = spearmanr(list(chi_betweenness.values()), list(chi_degree.values())).correlation
corr_betweeness_eigen_chi = spearmanr(list(chi_betweenness.values()), list(chi_eigen.values())).correlation
corr_degree_eigen_chi = spearmanr(list(chi_degree.values()), list(chi_eigen.values())).correlation


print(f'pagerank and betweeness: {corr_pagerank_betweeness_chi:3f}')
print(f'pagerank and degree: {corr_pagerank_degree_chi:3f}')
print(f'pagerank and eigen: {corr_pagerank_eigen_chi:3f}')
print(f'betweeness and degree: {corr_betweenness_degree_chi:3f}')
print(f'betweeness and eigen: {corr_betweeness_eigen_chi:3f}')
print(f'degree and eigen: {corr_degree_eigen_chi:3f}')
# Out:
# pagerank and betweeness: 0.914285
# pagerank and degree: 0.960319
# pagerank and eigen: 0.857824
# betweeness and degree: 0.864702
# betweeness and eigen: 0.765184
# degree and eigen: 0.947239

# %%
# find the Spearman's rank correlation among the four centrality scores on Caltech
# TODO. 3pts
corr_pagerank_betweeness_cal = spearmanr(list(cal_pagerank.values()), list(cal_betweenness.values())).correlation
corr_pagerank_degree_cal = spearmanr(list(cal_pagerank.values()), list(cal_degree.values())).correlation
corr_pagerank_eigen_cal = spearmanr(list(cal_pagerank.values()), list(cal_eigen.values())).correlation
corr_betweenness_degree_cal = spearmanr(list(cal_betweenness.values()), list(cal_degree.values())).correlation
corr_betweeness_eigen_cal = spearmanr(list(cal_betweenness.values()), list(cal_eigen.values())).correlation
corr_degree_eigen_cal = spearmanr(list(cal_degree.values()), list(cal_eigen.values())).correlation


print(f'pagerank and betweeness: {corr_pagerank_betweeness_cal:3f}')
print(f'pagerank and degree: {corr_pagerank_degree_cal:3f}')
print(f'pagerank and eigen: {corr_pagerank_eigen_cal:3f}')
print(f'betweeness and degree: {corr_betweenness_degree_cal:3f}')
print(f'betweeness and eigen: {corr_betweeness_eigen_cal:3f}')
print(f'degree and eigen: {corr_degree_eigen_cal:3f}')
# Out:
# pagerank and betweeness: 0.901068
# pagerank and degree: 0.973924
# pagerank and eigen: 0.943968
# betweeness and degree: 0.876931
# betweeness and eigen: 0.830905
# degree and eigen: 0.985805

# %% [markdown]
# ### For Chicago and Caltech respecitively, which centrality score pair has the most correlation? Give your insights on why the two scores in this pair have the most correlation. 4pts.
#
# #### <font color="red">Please type your response here.</font>
#
# Pair that has the most correlation:
#
# 1. Chicago: **PageRank** and **Degree** (0.960319)
#
#     Insights:
#     * PageRank is highly dependent on the number of connections a node has (i.e., its degree).
#     * Since Chicago's social network seems to have a more evenly distributed connectivity (as seen in the small degree standard deviation), the number of direct connections (Degree Centrality) largely dictates how influential a node is in the network.
#     * This strong correlation suggests that in Chicago’s network, having more direct connections is the dominant factor in determining a node’s importance in the PageRank algorithm.
#
# 2. Caltech: **Degree** and **Eigenvector** (0.985805)
#
#     Insights:
#     * Eigenvector Centrality measures not just how many connections a node has, but how *important* those connections are.
#     * The near-perfect correlation (0.986) suggests that nodes with a high degree are also connected to other well-connected nodes in Caltech's network.
#     * This means that in Caltech's network, high-degree nodes are likely to be in *influential* clusters rather than being isolated hubs.
#     * The larger standard deviations in Caltech’s degree distribution (compared to Chicago) indicate a more hierarchical network structure, where some nodes have significantly more connections than others, reinforcing the influence of Degree on Eigenvector Centrality.

# %% [markdown]
# ### Compare the four centrality score measures to Clustering Coefficient

# %%
# compute the correlation between each centrality score and clustering coefficient on Chicago
# TODO. 3pts
# compute the clustering coefficient
clustering_coeff_chi = nx.clustering(G_chicago)
corr_pagerank_cluster_chi = spearmanr(list(chi_pagerank.values()), list(clustering_coeff_chi.values())).correlation
corr_betweeness_cluster_chi = spearmanr(list(chi_betweenness.values()), list(clustering_coeff_chi.values())).correlation
corr_degree_cluster_chi = spearmanr(list(chi_degree.values()), list(clustering_coeff_chi.values())).correlation
corr_eigen_cluster_chi = spearmanr(list(chi_eigen.values()), list(clustering_coeff_chi.values())).correlation


print(f'pagerank and clustering: {corr_pagerank_cluster_chi:.3f}')
print(f'betweeness and clustering: {corr_betweeness_cluster_chi:.3f}')
print(f'degree and clustering: {corr_degree_cluster_chi:.3f}')
print(f'eigen and clustering: {corr_eigen_cluster_chi:.3f}')
# Out:
# pagerank and clustering: -0.354
# betweeness and clustering: -0.426
# degree and clustering: -0.287
# eigen and clustering: -0.208

# %%
# compute the correlation between each centrality score and clustering coefficient on Caltech
# TODO. 3pts
clustering_coeff_cal = nx.clustering(G_caltech)
corr_pagerank_cluster_cal = spearmanr(list(cal_pagerank.values()), list(clustering_coeff_cal.values())).correlation
corr_betweeness_cluster_cal = spearmanr(list(cal_betweenness.values()), list(clustering_coeff_cal.values())).correlation
corr_degree_cluster_cal = spearmanr(list(cal_degree.values()), list(clustering_coeff_cal.values())).correlation
corr_eigen_cluster_cal = spearmanr(list(cal_eigen.values()), list(clustering_coeff_cal.values())).correlation


print(f'pagerank and clustering: {corr_pagerank_cluster_cal:.3f}')
print(f'betweeness and clustering: {corr_betweeness_cluster_cal:.3f}')
print(f'degree and clustering: {corr_degree_cluster_cal:.3f}')
print(f'eigen and clustering: {corr_eigen_cluster_cal:.3f}')
# Out:
# pagerank and clustering: -0.430
# betweeness and clustering: -0.541
# degree and clustering: -0.373
# eigen and clustering: -0.329

# %% [markdown]
# ### For Chicago and Caltech respecitively, among the four centrality scores, which one has the least correlation with the clustering coefficient? Please give your insights. 4pts
#
# #### <font color="red">Please type your response here.</font>
#
# 1. Understanding the Relationship: **Clustering** Coefficient measures transitivity, i.e. how well a node’s neighbors are connected to each other. **Eigenvector** Centrality measures a node's importance based on its connections to other important nodes. It doesn't directly depend on how clustered the neighbors are but rather on their overall importance in the network.
#
# 2. Chicago: Eigenvector Centrality (-0.208)
#     * Insights:
#         1. The weak negative correlation suggests that in Chicago's network, being well-connected to *influential* nodes does not necessarily mean being in a tightly clustered group.
#         2. This could indicate a more de-centralised network: *important* nodes (high eigenvector scores) are *spread* across different groups, rather than forming dense communities.
#
# 3. Caltech: Eigenvector Centrality (-0.329)
#     * Insights:
#         1. The slightly stronger negative correlation (compared to Chicago) in Caltech suggests that nodes with high eigenvector centrality are *less likely* to be in clustered groups.
#         2. This could indicate a more *hierarchical* structure, where highly influential nodes serve as bridges between separate groups rather than being within dense clusters.
#
# Overall, the weak correlation between eigenvector centrality and clustering in both unis suggests that important individuals are not like the center of a closely knit group but more spread out.

# %% [markdown]
# ## Analysis of Link Prediction
# ### Conduct link prediction on Caltech

# %%
edges = list(G_caltech.edges)

# note that G_caltech is an undirected graph
# if there is an edge between node a and b, 
# the edge list will only contain (a, b) or (b, a) to save space, where a<=b or b<=a respectively
edges[:10]
# Out:
# [(0, 4),
#  (0, 30),
#  (0, 35),
#  (0, 38),
#  (0, 42),
#  (0, 60),
#  (0, 62),
#  (0, 89),
#  (0, 95),
#  (0, 100)]

# %%
# from edges, sample 75% training edges and 25% test edges
# both edges_train and edges_test should be a list of edges
# TODO. 2pts.

import random
# Train-Test split
random.shuffle(edges)
split_idx = int(0.75 * len(edges))
edges_train = edges[:split_idx]
edges_test = edges[split_idx:]


print(len(edges_train))
print(len(edges_test))

# construct a training Graph based on training edges
G_train = nx.from_edgelist(edges_train)
G_train.add_nodes_from(G_caltech.nodes)
print(G_train)
# Out:
# 12492
# 4164
# Graph with 769 nodes and 12492 edges

# %%
# we want the algorithm to score all the possible edges except those in the training set
G_complete = nx.complete_graph(G_caltech.number_of_nodes())
edges_complete = list(G_complete.edges)
edges_to_score = list(set(edges_complete) - set(edges_train))
print(len(edges_to_score))
# Out:
# 282804

# %%
# link prediction using Adamic-Adar index
# you need to score every edge in edges_to_score
# edge_score_ada should be a dictionary {(u, v): score}
# TODO. 3pts
edge_score_ada = {(u, v): score for u, v, score in nx.adamic_adar_index(G_train, edges_to_score)}

print(len(edge_score_ada))


# plot a histogram of all the scores in edge_score_ada
# TODO. 2pts
plt.hist(edge_score_ada.values(), bins=50, alpha=0.7, color='blue')
plt.xlabel('Adamic-Adar Score')
plt.ylabel('Frequency')
plt.title('Distribution of Adamic-Adar Scores')
plt.show()
# Out:
# 282804

# %%
# link prediction using Jaccard Coefficient
# you need to score every edge in edges_to_score
# edge_score_jac should be a dictionary {(u, v): score}
# TODO. 3pts.
edge_score_jac = {(u, v): score for u, v, score in nx.jaccard_coefficient(G_train, edges_to_score)}


print(len(edge_score_jac))

# plot a histogram of all the scores in edge_score_jac
# TODO. 2pts
plt.hist(edge_score_jac.values(), bins=50, alpha=0.7, color='green')
plt.xlabel('Jaccard Coefficient Score')
plt.ylabel('Frequency')
plt.title('Distribution of Jaccard Coefficient Scores')
plt.show()
# Out:
# 282804

# %%
# the link prediction evaluation of the entire graph is based on that of each node
# we only evaluate nodes that have a degree >= 20 and have gender label 1 or 2
from collections import Counter
deg = Counter(list(sum(edges_to_score, ())))
nodes_to_eval = [k for k, v in deg.items() if v >= 20]
nodes_to_eval = [node for node in nodes_to_eval if caltech_gender[node] != 0]

from collections import Counter
print(f'Gender count in nodes_to_eval: {Counter(caltech_gender[nodes_to_eval])}')
# Out:
# Gender count in nodes_to_eval: Counter({np.int64(2): 475, np.int64(1): 228})

# %%
def eval_link_prediction(nodes_to_eval, edge_score, gender, edges_test, k):
    """
    :nodes_to_eval (list): a list of nodes to evaluate
    :edge_score (dict): the predicted scores for edges in edges_to_score
    :gender (list): the gender list for all nodes in the graph
    :edges_test (list): the edge list of the test edges
    :k (int): the k in precision@k
    Return the average precision on nodes, the average precision for gender1 nodes, 
    and the average precision for gender2 nodes.
    
    Hint:
    For each node in nodes_to_eval, 
    retrieve the top-k incident edges on this node ranked by the predicted scores given in edge_score.
    Count how many retrieved edges are actually in edges_test.
    In this way, we can obtain the precision of predicted links for this node.
    Compute the precisions for all nodes in nodes_to_eval, return the avearge precision.
    Similarly, compute the average precision for only nodes with gender1/gender2 in nodes_to_eval.

    """
    #TODO. 10pts.
    precisions = []
    precisions_gender1 = []
    precisions_gender2 = []
    
    for node in nodes_to_eval:
        # Get all edges involving this node and their scores
        node_edges = [(u, v) for (u, v) in edge_score if u == node or v == node]
        node_scores = [(edge, edge_score[edge]) for edge in node_edges]
        
        # Sort edges by score in descending order
        node_scores.sort(key=lambda x: x[1], reverse=True)
        top_k_edges = [edge for edge, score in node_scores[:k]]
        
        # Compute precision@k
        hits = sum(1 for edge in top_k_edges if edge in edges_test or (edge[1], edge[0]) in edges_test)
        precision_k = hits / k
        precisions.append(precision_k)
        
        if gender[node] == 1:
            precisions_gender1.append(precision_k)
        elif gender[node] == 2:
            precisions_gender2.append(precision_k)
    
    # Compute average precision values
    precision = np.mean(precisions) if precisions else 0
    precision_gender1 = np.mean(precisions_gender1) if precisions_gender1 else 0
    precision_gender2 = np.mean(precisions_gender2) if precisions_gender2 else 0
    
    return precision, precision_gender1, precision_gender2


# a test case
# this test graph has six nodes [0, 1, 2, 3, 4, 5]
nodes_to_eval_example = [0,1,2,4]
edge_score_example = {(0, 1): 0.27, (0, 2): 0.39, (0, 3): 0.32, 
                      (1, 2): 0.3, (1, 4): 0.7,  (1, 5): 0.67, 
                      (2, 4): 0.45, (2, 5): 0.58, (4, 5): 0.9}
gender_example = [2,1,1,2,2,1]
edges_test_example = [(0, 3), (1,4), (1, 5), (2, 3), (2, 5), (3, 4)]
print(eval_link_prediction(nodes_to_eval_example, edge_score_example, gender_example, edges_test_example, 1))
print(eval_link_prediction(nodes_to_eval_example, edge_score_example, gender_example, edges_test_example, 2))
# Out:
# (np.float64(0.5), np.float64(1.0), np.float64(0.0))
# (np.float64(0.625), np.float64(0.75), np.float64(0.5))

# %%
for algo in ['adamic-adar', 'jaccard']:
    print(f'Evaluating link prediction on {algo}')
    for k in [5, 10, 20]:
        edge_score = edge_score_ada if algo == 'adamic-adar' else edge_score_jac
        precision, precision_gender1, precision_gender2 = eval_link_prediction(nodes_to_eval, 
                                                                              edge_score,
                                                                              caltech_gender,
                                                                              edges_test,
                                                                              k)
        print(f'precision@{k}: {precision:.3f}, precision@{k} for gender1: {precision_gender1: .3f}, precision@{k} for gender2: {precision_gender2:.3f}, precision@{k} diff: {precision_gender1-precision_gender2: .3f}')
    print()
# Out:
# Evaluating link prediction on adamic-adar
# precision@5: 0.409, precision@5 for gender1:  0.448, precision@5 for gender2: 0.389, precision@5 diff:  0.059
# precision@10: 0.330, precision@10 for gender1:  0.367, precision@10 for gender2: 0.312, precision@10 diff:  0.056
# precision@20: 0.244, precision@20 for gender1:  0.273, precision@20 for gender2: 0.230, precision@20 diff:  0.043
#
# Evaluating link prediction on jaccard
# precision@5: 0.364, precision@5 for gender1:  0.417, precision@5 for gender2: 0.339, precision@5 diff:  0.078
# precision@10: 0.304, precision@10 for gender1:  0.349, precision@10 for gender2: 0.283, precision@10 diff:  0.066
# precision@20: 0.232, precision@20 for gender1:  0.261, precision@20 for gender2: 0.218, precision@20 diff:  0.043

# %% [markdown]
# ### 1) On which gender the algorithms give better precision?  Give your insights on that. 3pts.
# ### 2 Which algorithm is more fair (lower precision gap)? Please give your insights on that. (Hint: Understand how the two algorithms work, and refer to the calculated centrality scores on Caltech. However, you don't have to follow this hint to explain). 5pts.
#
# #### <font color="red">Please type your response here.</font>
#
# #### Q1
#
# * **Adamic-Adar** consistently gives higher precision for **gender1** compared to **gender2**.
#
#     **Precision@5**: 0.448 (gender1) vs. 0.389 (gender2) → **diff: 0.059**
#
#     **Precision@10**: 0.367 (gender1) vs. 0.312 (gender2) → **diff: 0.056**
#
#     **Precision@20**: 0.273 (gender1) vs. 0.230 (gender2) → **diff: 0.043**
#
# * **Jaccard Coefficient** also favors **gender1**, but with slightly larger gaps.
#
#     **Precision@5**: 0.417 (gender1) vs. 0.339 (gender2) → **diff: 0.078**
#
#     **Precision@10**: 0.349 (gender1) vs. 0.283 (gender2) → **diff: 0.066**
#
#     **Precision@20**: 0.261 (gender1) vs. 0.218 (gender2) → **diff: 0.043**
#
# ##### Insights:
# 1. The algorithms show **higher precision for gender1**, meaning that they are more effective at predicting links for this group.
#
# 2. This could be due to structural properties of the graph (e.g., gender1 might have more connections, higher clustering, or greater centrality).
#
# 3.  The differences in precision suggest a possible bias in network structure, where gender1 may have more strongly connected nodes or a more predictable link formation pattern.
#
# #### Q2
#
# Fairness is measured by the precision gap (difference in precision between genders). Lower precision gaps mean a more balanced prediction performance.
#
# * Adamic-Adar precision gaps:
#
#     @5: 0.059
#
#     @10: 0.056
#
#     @20: 0.043
#
# * Jaccard precision gaps:
#
#     @5: 0.078
#
#     @10: 0.066
#
#     @20: 0.043
#
# Which is fairer?
#
# **Adamic-Adar** has a lower precision gap at every level, meaning it is the more *fair* algorithm.
#
# **Jaccard** Coefficient shows larger discrepancies, particularly at precision@5 and precision@10, indicating more gender *disparity*.
#
# ##### Insights:
# * Why is Adamic-Adar more fair?
#
#     Adamic-Adar favors nodes with **highly shared neighbors**, meaning it is more influenced by local clustering. This may make it less biased towards network-wide degree imbalances, leading to smaller precision gaps.
#
# * Why is Jaccard less fair?
#
#     Jaccard relies on the **relative fraction of shared neighbors**, which can be more sensitive to low-degree nodes. If one gender has fewer common neighbors in the network, the Jaccard score may be systematically lower, leading to greater disparities.
